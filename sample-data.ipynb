# %%
import os
import pandas as pd

# %%
DATASET_PATH = 'C:/Users/ignacio/workspace/stanford/cs230/'
TRAIN_FILE = 'CheXpert-v1.0-small/train.csv'
VALIDATION_FILE = 'CheXpert-v1.0-small/validation.csv'

# %%
train_df = pd.read_csv(DATASET_PATH +  TRAIN_FILE)
train_df.head()
# Out:
#                                                 Path     Sex  Age  \
# 0  CheXpert-v1.0-small/train/patient00001/study1/...  Female   68
# 1  CheXpert-v1.0-small/train/patient00002/study2/...  Female   87
# 2  CheXpert-v1.0-small/train/patient00002/study1/...  Female   83
# 3  CheXpert-v1.0-small/train/patient00002/study1/...  Female   83
# 4  CheXpert-v1.0-small/train/patient00003/study1/...    Male   41
#
#   Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum  Cardiomegaly  \
# 0         Frontal    AP         1.0                         NaN           NaN
# 1         Frontal    AP         NaN                         NaN          -1.0
# 2         Frontal    AP         NaN                         NaN           NaN
# 3         Lateral   NaN         NaN                         NaN           NaN
# 4         Frontal    AP         NaN                         NaN           NaN
#
#    Lung Opacity  Lung Lesion  Edema  Consolidation  Pneumonia  Atelectasis  \
# ...

# %%
df = train_df[train_df['Frontal/Lateral'].eq('Frontal')]
df = df[df['AP/PA'].eq('PA')]
df = df.fillna(0)
df
# Out:
#                                                      Path     Sex  Age  \
# 5       CheXpert-v1.0-small/train/patient00004/study1/...  Female   20
# 7       CheXpert-v1.0-small/train/patient00005/study1/...    Male   33
# 16      CheXpert-v1.0-small/train/patient00009/study1/...    Male   76
# 18      CheXpert-v1.0-small/train/patient00010/study1/...  Female   50
# 20      CheXpert-v1.0-small/train/patient00011/study13...  Female   22
# ...                                                   ...     ...  ...
# 188235  CheXpert-v1.0-small/train/patient44899/study3/...  Female   90
# 203254  CheXpert-v1.0-small/train/patient51052/study1/...    Male   58
# 205963  CheXpert-v1.0-small/train/patient52592/study2/...  Female   32
# 214290  CheXpert-v1.0-small/train/patient57768/study2/...  Female   63
# 219095  CheXpert-v1.0-small/train/patient60658/study1/...  Female   60
#
#        Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum  \
# ...

# %%
cardiomegaly = df[df['Cardiomegaly'].eq(1)]
cardiomegaly
# Out:
#                                                      Path     Sex  Age  \
# 16      CheXpert-v1.0-small/train/patient00009/study1/...    Male   76
# 74      CheXpert-v1.0-small/train/patient00023/study8/...    Male   67
# 134     CheXpert-v1.0-small/train/patient00044/study7/...  Female   49
# 136     CheXpert-v1.0-small/train/patient00044/study6/...  Female   49
# 187     CheXpert-v1.0-small/train/patient00061/study2/...    Male   90
# ...                                                   ...     ...  ...
# 143901  CheXpert-v1.0-small/train/patient34574/study5/...    Male   81
# 143955  CheXpert-v1.0-small/train/patient34593/study1/...    Male   45
# 178015  CheXpert-v1.0-small/train/patient41739/study1/...  Female   62
# 188235  CheXpert-v1.0-small/train/patient44899/study3/...  Female   90
# 205963  CheXpert-v1.0-small/train/patient52592/study2/...  Female   32
#
#        Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum  \
# ...

# %%
no_finding = df[df['No Finding'].eq(1)]
no_finding
# Out:
#                                                      Path     Sex  Age  \
# 5       CheXpert-v1.0-small/train/patient00004/study1/...  Female   20
# 7       CheXpert-v1.0-small/train/patient00005/study1/...    Male   33
# 18      CheXpert-v1.0-small/train/patient00010/study1/...  Female   50
# 40      CheXpert-v1.0-small/train/patient00013/study1/...    Male   36
# 58      CheXpert-v1.0-small/train/patient00021/study1/...  Female   36
# ...                                                   ...     ...  ...
# 143885  CheXpert-v1.0-small/train/patient34568/study1/...  Female   35
# 143917  CheXpert-v1.0-small/train/patient34582/study1/...    Male   53
# 143959  CheXpert-v1.0-small/train/patient34595/study1/...  Female   31
# 143961  CheXpert-v1.0-small/train/patient34596/study1/...    Male   42
# 219095  CheXpert-v1.0-small/train/patient60658/study1/...  Female   60
#
#        Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum  \
# ...

# %%
no_finding.sample(100)['Path'].iloc[0]
# Out:
# 'CheXpert-v1.0-small/train/patient31294/study2/view1_frontal.jpg'

# %%
import shutil

# %%
for idx, row in no_finding.iterrows():
    shutil.copy2(DATASET_PATH + row['Path'], DATASET_PATH + 'cs230-project/data/chexpert-cardio-nofinding/' + row['Path'].split('/')[2] + '_' +row['Path'].split('/')[3] + '_' + row['Path'].split('/')[4])
    
for idx, row in cardiomegaly.iterrows():
    shutil.copy2(DATASET_PATH + row['Path'], DATASET_PATH + 'cs230-project/data/chexpert-cardio-nofinding/' + row['Path'].split('/')[2] + '_' +row['Path'].split('/')[3] + '_' + row['Path'].split('/')[4])

# %%
#for idx, row in no_finding.sample(200).iterrows():
#    shutil.copy2(DATASET_PATH + row['Path'], DATASET_PATH + 'chexpert-validation/nofinding/' + row['Path'].split('/')[2] + '_' +row['Path'].split('/')[3] + '_' + row['Path'].split('/')[4])

# %%
#for idx, row in cardiomegaly.sample(200).iterrows():
#    shutil.copy2(DATASET_PATH + row['Path'], DATASET_PATH + 'chexpert-validation/cardiomegaly/' + row['Path'].split('/')[2] + '_' +row['Path'].split('/')[3] + '_' + row['Path'].split('/')[4])

# %%
#atelectasis = df[df['Atelectasis'].eq(1)]
#for idx, row in atelectasis.sample(200).iterrows():
    shutil.copy2(DATASET_PATH + row['Path'], DATASET_PATH + 'chexpert-validation/atelectasis/' + row['Path'].split('/')[2] + '_' +row['Path'].split('/')[3] + '_' + row['Path'].split('/')[4])

# %%
#c = df[df['Consolidation'].eq(1)]
#for idx, row in c.sample(200).iterrows():
#    shutil.copy2(DATASET_PATH + row['Path'], DATASET_PATH + 'chexpert-validation/consolidation/' + row['Path'].split('/')[2] + '_' +row['Path'].split('/')[3] + '_' + row['Path'].split('/')[4])

# %%
#c = df[df['Enlarged Cardiomediastinum'].eq(1)]
#for idx, row in c.sample(200).iterrows():
#   shutil.copy2(DATASET_PATH + row['Path'], DATASET_PATH + 'chexpert-validation/cardiomediastinum/' + row['Path'].split('/')[2] + '_' +row['Path'].split('/')[3] + '_' + row['Path'].split('/')[4])
